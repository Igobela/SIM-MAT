# %% [markdown]
# # T01- Markdown: Iñigo De Obeso

# %% [markdown]
# ### Datos generales:

# %% [markdown]
# Nací el 23 de marzo del 2002 aquí en Guadalajara y he permanecido aquí ***toda*** mi vida. Me apasionan mucho las finanzas al igual que cualquier tipo de arte *(música, pintura, escritura, etc)*. Por el momento trabajo en una constructora en la cual llevo más de un año trabajando como analista financiero donde manejo los flujos de diferentes edificios y sus estados bancarios.

# %% [markdown]
# ### Habilidades:

# %% [markdown]
#  - Habilidades culinarias: desde un huevo con catsup hasta una buena pizza a la leña.
#  - UNO: Soy un dios en este juego y estoy dispuesto a arruinar mis amistades con tal de ganar. (Preguntenle a Quique)
# ![OIP.jfif](attachment:OIP.jfif)
#                                                      ^ Este es Quique ^
#  - Toco instrumentos y a veces intento producir música.
#  - Eso es todo.

# %% [markdown]
# ### Mis bandas y artistas favoritos:

# %% [markdown]
# 1. David Bowie
# 2. Zoe
# 3. Kings of Leon
# 4. C. Tangana
# 5. AC / DC

# %% [markdown]
# ### Ecuaciones:

# %% [markdown]
# El profe dijo que pusieramos una ecuacion chida, así que ahí les va una:
# $(x^2+y^2-1)^3 = x^2 y^3$

# %% [markdown]
# ![Screenshot%202022-08-15%20173306.png](attachment:Screenshot%202022-08-15%20173306.png)

# %% [markdown]
# ### Un tema chido de mi carrera: El análisis financiero de los bienes raíces.

# %% [markdown]
# En una economía es muy común observar el cambio de valuación de activos, en especial el de la tierra y de los bienes raíces arriba de ella. Como ingeniero financiero es común simular y calcular la tendencia de la valoración de esta para preparar estrategías de inversión y desarrollo de proyectos. Adjunto una gráfica:
#
# ![precio-3t-2019-1060x410.png](attachment:precio-3t-2019-1060x410.png)
#
# En esta clase espero...
# - Poder generar simulaciones para apreciar el valor de metro cuadrado por región.
# - Saber si el mercado esta sobre valorado y mantener una postura resguardada o inclusó alzar precios para igualarlos a la competencia.
# - Tener en mente la estabilidad del mercado y estar atento a cualquier caída en el sector.
